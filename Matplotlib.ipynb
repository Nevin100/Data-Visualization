# %% [markdown]
# # Importing Libraries :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,5,11)
x

y = x ** 0.5
y
# Out:
# array([0.        , 0.70710678, 1.        , 1.22474487, 1.41421356,
#        1.58113883, 1.73205081, 1.87082869, 2.        , 2.12132034,
#        2.23606798])

# %% [markdown]
# # First Plot

# %%
# plot function :
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Pyplot :

# %%
# x-axis :
x = ['Monday','Tuesday','Wednesday','Thursday','Friday']

# y-axis :
y = [10,20,40,60,5]

#title:
plt.title("Bakery Sales :")

#xlabel
plt.xlabel("Days :")

#ylabel
plt.ylabel("Days :")

plt.plot(x,y)
plt.show()

# %% [markdown]
# # Pyplot Fuctions :

# %%
# 1.) plt.plot(x,y, {rest optional...}) --> plottig purpose 
# 2.) plt.title() --> Title Heading of the Plot
# 3.) plt.xlabel() & plt.ylabel() --> labels for x and y
# 4.) plt.show() --> To Show the plot

months = ['January','February', 'March', 'April' ]
sales = [5000,4000,6600,2000]

plt.title("Sales Graph -->")

plt.xlabel("Months Q1-->")
plt.ylabel("Sales in $-->")

plt.plot(months, sales, color='blue', linestyle='--', linewidth=1, marker='o')
plt.show()
